# %%
#We can concatenate two strings by f string, .join (),+ operator and .format method
a ="Hello"
b ="World"
result= a + " " + b
print(result)
# Out:
# Hello World

# %%
#Question 2
# + operator combines two or more strings directly while .join() combines multiple strings from an itrebile(list,tuple)

# %%
# Question 3: 
# by indexing
string = "python"
print(string[0])
print(string[1])
print(string[2])
print(string[3])
print(string[4])
print(string[5])
# Out:
# p
# y
# t
# h
# o
# n

# %%
# Question 4:
# len() is used to find the length of the string
string= "python"
print(len(string))
# Out:
# 6

# %%
# Question 5:
string= "python"
print(string.upper())
# Out:
# PYTHON

# %%
#Question 6:
string= "PYTHON CLASS"
print(string.lower())
# Out:
# python class

# %%
#Question7:
string= "This is python class"
string.replace("python","java")
# Out:
# 'This is java class'

# %%
#Question 8:
string= "This is python class"
string.split(" ")
# Out:
# ['This', 'is', 'python', 'class']

# %%
#Question 9:
string ="Python programmimg"
string.startswith("Python")
# Out:
# True

# %%
#Question 10:
string ="Python programming"
string.endswith("programming")
# Out:
# True

# %%
#Question 11:
string ="  Python class   "
string.strip()
# Out:
# 'Python class'

# %%
#Question 12:
string= "This is python class"
string.find("python")
# Out:
# 8

# %%
#Question 13:
string= "This is python python class"
string.count("python")
# Out:
# 2

# %%
#Question 14:
string= "Thisispythonclass"
string.isalpha()
# Out:
# True

# %%
#Question 15:
string = "12345"
string.isnumeric()
# Out:
# True

# %%
#Question 16:
string ="madam"
print(string[::-1])
# Out:
# madam

# %%
#Question 17:
string ="Python"
print(string[::-1])
# Out:
# nohtyP

# %%
#Question 18:
name ="Sachin"
age = 25
string ="My name is {} and i am {}" .format(name,age)
print(string)
# Out:
# My name is Sachin and i am 25

# %%
#Question 19:
string = "Hello World"
print(string[6:11:1])
# Out:
# World

# %%
#Question 20:
string = "Hello World"
string.replace("o","")
# Out:
# 'Hell Wrld'
